# %%
# PROJECT 1 
# Making a personal small dictionary without any if/else
print("Welcome to Dictionary")
Dictionary = {"abase":"cause to feel shame","benefit":"advantage","callow":"young and inexperienced","dally":"waste time","endear":"make attractive"}
print("Please tell the word whose meaning you want is:")
print("Also show your grace by taking a word from dictionary.")
Search = input()
print("The required meaning is:")
print(Dictionary[Search])
print("Thanks for using Dictionary")
# Out:
# Welcome to Dictionary
# Please tell the word whose meaning you want is:
# Also show your grace by taking a word from dictionary.
#  endear
# The required meaning is:
# make attractive
# Thanks for using Dictionary

# %%
# ARE YOU ELIGIBLE
print("What is your age?")
age = int(input())
if age<18:
    print("You cannot drive.")
elif age==18:
    print("We will think about you")
else:
    print("You can drive")
# Out:
# What is your age?
#  91
# You can drive

# %%
print("zara umar btao apni")
age=int(input())

if 18<age<=100:
    print("tum sb chla skte ho")
elif age==18:
    print("tum helicopter nai uda skte ho")
elif age>100:
    print("tum pagal mat banao")
else:
    print("tum beta kuch n chalao paidal jao")
# Out:
# zara umar btao apni
#  66
# tum sb chla skte ho

# %%
ope=input("enter the operation")
a=int(input("enter first number"))
b=int(input("enter the second number"))

if ope=="*" and a==56 and b==3:
    print(555)
elif ope=="+" and a==56 and b==9:
    print(77)
elif ope=="/" and a==56 and b==6:
    print(4)

elif ope=="*":
    print(a,"*",b,"=",a*b) 
elif ope=="+":
    print(a,"+",b,"=",a+b)
elif ope=="-":
    print(a,"-",b,"=",a-b)
elif ope=="/":
    print(a,"/",b,"=",a/b)
else:
    print("please select the definite operations like +-*/")
# Out:
# enter the operation *
# enter first number 56
# enter the second number 3
# 555

# %%
 # Just a practice problem on loops.
items = [int, float, "Harry", 16, 23 ,5,3 ,23, 5, 6, 23]
for item in items:
    if str(item).isnumeric() and item>=6:   #Here  str is used to type cast int,
                                             #  float into str
                                             
        print(item)
# Out:
# 16
# 23
# 23
# 6
# 23

# %%
n=18
number_of_guesses=1
print("Number of guesses is limited to only 3 times: ")
while (number_of_guesses<=3):
    guess_number = int(input("Guess the number :\n"))
    if guess_number<18:
        print("you enter less number please input greater number.\n")
    elif guess_number>18:
        print("you enter greater number please input smaller number.\n ")
    else:
        print("you won\n")
        print(number_of_guesses,"no.of guesses he took to finish.")
        break
    print(3-number_of_guesses,"no. of guesses left")
    number_of_guesses = number_of_guesses + 1

if(number_of_guesses>3):
    print("Game Over")
# Out:
# Number of guesses is limited to only 3 times:
# Guess the number :
#  20
# you enter greater number please input smaller number.
#
# 2 no. of guesses left
# Guess the number :
#  16
# you enter less number please input greater number.
#
# 1 no. of guesses left
# Guess the number :
#  17
# you enter less number please input greater number.
#
# 0 no. of guesses left
# Game Over

# %%
print("How Many Row You Want To Print")
one= int(input())
print("Type 1 Or 0")
two = int(input())
new =bool(two)
if new == True:
    for i in range(1,one+1):
        for j in range(1,i+1):
            print("*",end=" ")
        print()
elif new ==False:
    for i in range(one,0,-1):
        for j in range(1,i+1):
            print("*", end="")
        print()
# Out:
# How Many Row You Want To Print
#  5
# Type 1 Or 0
#  1
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
rows = int(input("Enter rows: "))
choice = int(input("Enter 1 or 0: "))

if choice == 1:
    for i in range(1, rows + 1):
        print("* " * i)

else:
    for i in range(rows, 0, -1):
        print("* " * i)
# Out:
# Enter rows:  6
# Enter 1 or 0:  0
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
 .bat {
    width: 1px;
    height: 1px;
    transform: scale(4);
    position: relative;
    left: -128px;
    top: -128px;
    -webkit-animation: 0.4s bat steps(1) infinite;
            animation: 0.4s bat steps(1) infinite;
 }
# Out:
#   Cell In[1], line 2
#     width: 1px;
#            ^
# SyntaxError: invalid decimal literal

# %%
import random
items=["rock","paper","scissor"]

computer=random.choice(items)

user=input("Rock Paper or Scissor:").lower()

print("Computer chooses",computer)
if user == computer:
    print("Match draw....!")

elif user == "rock" and computer == "scissor":
     print("User winnn!!!")

elif user == "paper" and computer == "rock":
     print("User win!!!")

elif user == "scissor"  and computer == "paper":
    print("Use win!!!")

else:
    print("Computer wins!!!")
# Out:
# Rock Paper or Scissor: pebble
# Computer chooses scissor
# Computer wins!!!

# %%
import random

items = ["rock", "paper", "scissor"]
computer = random.choice(items)

# 1. Loop until the user enters a valid choice
while True:
    user = input("Rock Paper or Scissor: ").lower()
    
    if user in items:
        break  # Valid input received, exit the loop
    else:
        print("Invalid input! Please choose either rock, paper, or scissor.\n")

print("Computer chooses", computer)

# 2. Rest of your game logic remains the same
if user == computer:
    print("Match draw....!")
elif user == "rock" and computer == "scissor":
    print("User winnn!!!")
elif user == "paper" and computer == "rock":
    print("User win!!!")
elif user == "scissor" and computer == "paper":
    print("User win!!!")
else:
    print("Computer wins!!!")
# Out:
# Rock Paper or Scissor:  pebble
# Invalid input! Please choose either rock, paper, or scissor.

# %%
# Snake Water Gun
import random

choices = ["snake", "water", "gun"]
player_score = 0
computer_score = 0

print("=== SNAKE, WATER, GUN ===")
print("Snake drinks Water | Water drowns Gun | Gun kills Snake")
print("Type 'quit' to stop playing.\n")

while True:
    player_choice = input("Enter snake, water, or gun: ").lower()

    if player_choice == "quit":
        print("Thanks for playing!")
        break

    if player_choice not in choices:
        print("Invalid choice. Please type snake, water, or gun.\n")
        continue

    computer_choice = random.choice(choices)
    print(f"Computer chose: {computer_choice}")

    if player_choice == computer_choice:
        print("It's a tie!\n")
    elif (
        (player_choice == "snake" and computer_choice == "water") or
        (player_choice == "water" and computer_choice == "gun") or
        (player_choice == "gun" and computer_choice == "snake")
    ):
        print("You win this round!\n")
        player_score += 1
    else:
        print("Computer wins this round!\n")
        computer_score += 1

    print(f"Score -> You: {player_score} | Computer: {computer_score}\n")

print(f"\nFinal Score -> You: {player_score} | Computer: {computer_score}")
# Out:
# === SNAKE, WATER, GUN ===
# Snake drinks Water | Water drowns Gun | Gun kills Snake
# Type 'quit' to stop playing.
# Enter snake, water, or gun:  gun
# Computer chose: water
# Computer wins this round!
#
# Score -> You: 0 | Computer: 1
# Enter snake, water, or gun:  snake
# Computer chose: water
# You win this round!
#
# Score -> You: 1 | Computer: 1
# Enter snake, water, or gun:  QUIT
# Thanks for playing!
#
# Final Score -> You: 1 | Computer: 1

# %%
import random
number_of_win=1
print("number of win is limited just 5 time")#this is limited to play 5 match
x="Gun"#this is list
y="Water"
o="snake"
while (number_of_win<5):
    f=str(input("enter your character::Gun,Water,Snake:"))
# if inp=gun and computer=water ==computer win the match...inp=water and com=gun then you can on the match ...
    #if you want to vs computer then you can check my game and win the match .................
    list1 = ["Gun", "Water", "Snake"]
    choice = random.choice(list1)
    if f =="Gun":
        print(choice)
    elif f=="Water":
        print(choice)
    elif f=="Snake":
        print(choice)
        continue

    if choice=="Gun" and f=="snake":
        print("computer win")
    elif choice=="Snake" and f=="Gun":
        print("you won")
    elif choice=="Water" and f=="Gun":
        print("computer win")
    elif choice=="Gun" and f=="Water":
        print("you win")
    elif choice=="Water" and f=="Snake":
        print("You win")
    elif choice=="Snake" and f=="Water":
        print("computer win")
    elif choice==f:
        print("You are equal in computer ..")
    else:
        print("You are not my character if you want to play this game use only mine character")
    print(5-number_of_win,"To win the match you can play match")
    number_of_win=number_of_win+1
    if number_of_win>5:
        print("Game over")
        print()
        break
